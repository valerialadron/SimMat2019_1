# %% [markdown]
# # Ajuste de curvas
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/a/a8/Regression_pic_assymetrique.gif" width="400px" height="125px" />
#
# El **ajuste de curvas** es el proceso de construir una curva (función), que sea el mejor ajuste a una serie de puntos, posiblemente sujeto a restricciones. Las curvas ajustadas pueden ser usadas como ayuda en la visualización de datos, para inferir valores de una función donde no hay datos disponibles, y para resumir la relación entre variables.
#
# Existen dos enfoques generales para el ajuste de curvas que se distinguen entre sí en función de la cantidad de error asociado con los datos.
#
# - Primero, cuando los datos muestran un grado significativo de error o "ruido", la estrategia es derivar una curva única que represente la tendencia general de los datos. Un enfoque de esta naturaleza se llama regresión de mínimos cuadrados.
#
# - Segundo, cuando se sabe que los datos son muy precisos, el enfoque básico es ajustar una curva o una serie de curvas que pasan directamente a través de cada uno de los puntos. La estimación de valores entre puntos discretos conocidos se llama interpolación.
#
#
# **Referencia**:
# - **Steven C. Chapra, Métodos Numéricos para Ingenieros, 6ª ed., Mc Graw Hill.**
# ___

# %% [markdown]
# ## 0. Introducción
#
# Consideremos un polinomio de grado uno:
#
# $$y = \beta_1 x + \beta_0.$$
#
# Esta es una **línea recta** que tiene pendiente $\beta_1$. Sabemos que habrá una línea conectando dos puntos cualesquiera. Por tanto, *una ecuación polinómica de primer grado es un ajuste perfecto entre dos puntos*.
#
# Si consideramos ahora un polinomio de segundo grado,
#
# $$y = \beta_2 x^2 + \beta_1 x + \beta_0,$$
#
# este se ajustará exactamente a tres puntos. Si aumentamos el grado de la función a la de un polinomio de tercer grado, obtenemos:
#
# $$y = \beta_3 x^3 + \beta_2 x^2 + \beta_1 x + \beta_0,$$
#
# que se ajustará a cuatro puntos.
#
# **Ejemplos**
# 1. Encontrar la línea recta que pasa exactamente por los puntos $(0,1)$ y $(1,0)$.
# 2. Encontrar la parábola que pasa exactamente por los puntos $(-1,1)$, $(0,0)$ y $(1,1)$.
#
# **Solución**
# 1. Consideramos $y=\beta_1 x + \beta_0$. Evaluando en el punto $(0,1)$, obtenemos $\beta_1(0) + \beta_0 = 1$. Ahora, evaluando en el punto $(1,0)$, obtenemos $\beta_1(1) + \beta_0 = 0$. De esta manera,
# $$\left[\begin{array}{cc} 1 & 0 \\ 1 & 1\end{array}\right]\left[\begin{array}{c} \beta_0 \\ \beta_1\end{array}\right]=\left[\begin{array}{c} 1 \\ 0\end{array}\right].$$
# Resolviendo, $\beta_0=-\beta_1=1$.

# %%
# Importar numpy y el matplotlib.pyplot
import numpy as np
import matplotlib.pyplot as plt

# %%
# Encontrar \beta_0 y \beta_1 resolviendo el sistema
A=np.array([[1,0],[1,1]])
B=np.array([1,0])

beta= np.linalg.inv(A).dot(B)
beta
#beta = np.dot(np.linalg.inv(A), b)
# Out:
# array([ 1., -1.])

# %%
# Graficar la recta encontrada junto con los puntos
x = np.array([0, 1])
y = np.array([1, 0])
plt.figure(figsize=(8,6))
plt.plot(x, y, 'ro', ms=5, label='Puntos')
plt.plot(x, beta[0]+beta[1]*x, label='Recta ajustada')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
plt.grid()

# %% [markdown]
# 2. Consideramos $y=\beta_2 x^2 + \beta_1 x + \beta_0$. Evaluando en el punto $(-1,1)$, obtenemos $\beta_2(-1)^2 + \beta_1(-1) + \beta_0 = 1$. Ahora, evaluando en el punto $(0,0)$, obtenemos $\beta_2(0)^2 + \beta_1(0) + \beta_0 = 0$. Finalmente, evaluando en el punto $(1,1)$, obtenemos $\beta_2(1)^2 + \beta_1(1) + \beta_0 = 1$. De esta manera,
# $$\left[\begin{array}{ccc} 1 & -1 & 1 \\ 1 & 0 & 0 \\ 1 & 1 & 1 \end{array}\right]\left[\begin{array}{c} \beta_0 \\ \beta_1 \\ \beta_2 \end{array}\right]=\left[\begin{array}{c} 1 \\ 0 \\ 1 \end{array}\right].$$
# Resolviendo, $\beta_0=\beta_1=0$ y $\beta_2=1$.

# %%
# Encontrar \beta_0, \beta_1 y \beta_2
A=np.array([[1,-1,1],[1,0,0],[1,1,1]])
B=np.array([1,0,1])

beta= np.linalg.inv(A).dot(B)
beta
# Out:
# array([0., 0., 1.])

# %%
# Graficar la parabola junto con los puntos
x = np.array([-1,0, 1])
y = np.array([1, 0, 1])
plt.figure(figsize=(8,6))
plt.plot(x, y, 'ro', ms=5, label='Puntos')
xp=np.linspace(-1,1)
plt.plot(xp, beta[0]+beta[1]*xp+beta[2]*xp**2, label='Parabola ajustada')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
plt.grid()

# %% [markdown]
# ## ¿Qué tienen en común los anteriores problemas?
# Las curvas están completamente determinadas por los puntos (datos limpios, suficientes y necesarios).
#
# Esto se traduce en que, al llevar el problema a un sistema de ecuaciones lineales, existe una única solución.
#
# ¿Tendremos datos así en la vida real?
#
# La realidad es que los datos que encontraremos en nuestra vida profesional se parecen más a esto...

# %%
# Crear un conjunto de puntos ruidosos a partir de una recta
x = np.linspace(0, 1, 50)
y = 2+10*x+np.random.randn(50)

# %%
# Graficar
plt.figure(figsize=(8,6))
plt.plot(x, y, '*')
plt.xlabel('x')
plt.ylabel('y')
plt.grid()

# %% [markdown]
# ## ¿Cómo ajustamos una curva a esto?

# %% [markdown]
# ## 1. Problema básico
#
# Consideramos que tenemos un conjunto de n pares ordenados de datos $(x_i,y_i)$, para $i=1,2,\dots,n$.
#
# ### ¿Cuál es la recta que mejor se ajusta a estos datos?
# Consideramos entonces ajustes de la forma $\hat{f}(x) = \beta_0+\beta_1 x = \left[1 \quad x\right]\left[\begin{array}{c} \beta_0 \\ \beta_1 \end{array}\right]=\left[1 \quad x\right]\boldsymbol{\beta}$ (lineas rectas).
#
# Para decir '**El mejor**', tenemos que definir algún sentido en que una recta se ajuste **mejor** que otra.
#
# **Mínimos cuadrados**: el objetivo es seleccionar los coeficientes $\boldsymbol{\beta}=\left[\beta_0 \quad \beta_1 \right]^T$, de forma que la función evaluada en los puntos $x_i$ ($\hat{f}(x_i)$) aproxime los valores correspondientes $y_i$.
#
# La formulación por mínimos cuadrados, encuentra los $\boldsymbol{\beta}=\left[\beta_0 \quad \beta_1 \right]^T$ que minimiza
# $$\sum_{i=1}^{n}(y_i-\hat{f}(x_i))^2=\sum_{i=1}^{n}(y_i-\left[1 \quad x_i\right]\boldsymbol{\beta})^2=\left|\left|\boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\right|\right|^2,$$
#
# donde $\boldsymbol{y}=\left[y_1\quad\dots\quad y_n\right]^T$, y $\boldsymbol{X}=\left[\begin{array}{ccc}1 & x_1\\ \vdots & \vdots \\ 1 & x_n\end{array}\right].$ Esto es,
#
# $$\boldsymbol{\beta}^{ls} = \arg \min_{\boldsymbol{\beta}} \left|\left|\boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\right|\right|^2$$

# %% [markdown]
# Para llevar a cabo la anterior minimización, la librería `SciPy` en su módulo `optimize` contiene la función `minimize`.

# %%
# Importar el módulo optimize de la librería scipy
import scipy.optimize as opt

# %%
# Función minimize
help(opt.minimize)
# Out:
# Help on function minimize in module scipy.optimize._minimize:
#
# minimize(fun, x0, args=(), method=None, jac=None, hess=None, hessp=None, bounds=None, constraints=(), tol=None, callback=None, options=None)
#     Minimization of scalar function of one or more variables.
#
#     Parameters
#     ----------
#     fun : callable
#         The objective function to be minimized.
#
#             ``fun(x, *args) -> float``
#
#         where x is an 1-D array with shape (n,) and `args`
#         is a tuple of the fixed parameters needed to completely
#         specify the function.
#     x0 : ndarray, shape (n,)
#         Initial guess. Array of real elements of size (n,),
#         where 'n' is the number of independent variables.
#     args : tuple, optional
#         Extra arguments passed to the objective function and its
#         derivatives (`fun`, `jac` and `hess` functions).
#     method : str or callable, optional
#         Type of solver.  Should be one of
#
# ...

# %% [markdown]
# Parámetros importantes:
# - fun: función $f(x)$, se debe definir antes de llamar minimize, como `def f(x): ... return ...`
# - x0: valor inicial. En una función no lineal, en general, hay múltiples mínimos. Dependiendo de los valores iniciales caerá en uno de esos mínimos. Se ingresa como $x0 = \text{np.array}([x_{01},\dots,x_{0n}])$.
# - bounds: como en linprog.
# - constraints: funciones que definen las restricciones $g_i(x)$ y $h_j(x)$. Se definen igual que $f(x)$ y se ingresan como {'ineq': g_i, 'eq': h_j}.

# %% [markdown]
# Primero debemos construir la función objetivo y el valor inicial:

# %%
# Definir funcion objetivo y punto inicial
def objmc(beta,x,y):
    return np.sum((y-(beta[0]+beta[1]*x))**2)

# %%
beta0=[0,0]

# %%
# Mostrar
beta0
# Out:
# [0, 0]

# %% [markdown]
# ¿Qué tan bien luce el ajuste?

# %%
# Coeficientes \beta_0 y \beta_1
rta1=opt.minimize(objmc,beta0,args=(x,y))
rta1
# Out:
#       fun: 55.41106375997875
#  hess_inv: array([[ 0.03888134, -0.05768492],
#        [-0.05768492,  0.11531871]])
#       jac: array([-4.76837158e-06, -1.43051147e-06])
#   message: 'Optimization terminated successfully.'
#      nfev: 28
#       nit: 6
#      njev: 7
#    status: 0
#   success: True
#         x: array([2.67626367, 8.96659418])

# %%
# Grafica de los puntos y la recta ajustada
plt.figure(figsize=(8,6))
plt.plot(x, y, '*')
plt.plot(x, rta1.x[0]+rta1.x[1]*x, '-k', label='recta ajustada')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
plt.grid()

# %% [markdown]
# La anterior idea se puede extender a ajuste polinomial...

# %% [markdown]
# ## 2. Ajuste polinomial
#
# Ahora, considere el siguiente conjunto de datos...

# %%
# Generamos 100 puntos ruidosos a partir de una senoidal
n = 100
x = np.linspace(np.pi/3, 7*np.pi/4, n)
y = np.sin(x) + np.random.normal(0,0.15,len(x))


plt.figure(figsize=(8,6))
plt.plot(x, y, '*')
plt.ylabel('y')
plt.xlabel('x')
plt.grid()

# %% [markdown]
# ### 2.1. ¿Se ajustará bien una recta?

# %%
# Definir funcion objetivo y valor inicial
def objmc(beta,x,y):
    return np.sum((y-(beta[0]+beta[1]*x))**2)
beta0=[0,0]

# %%
# Resolver
rta1=opt.minimize(objmc,beta0,args=(x,y))
rta1
# Out:
#       fun: 6.343175960307417
#  hess_inv: array([[ 0.03679708, -0.00971647],
#        [-0.00971647,  0.00296914]])
#       jac: array([-4.17232513e-07, -4.76837158e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 24
#       nit: 4
#      njev: 6
#    status: 0
#   success: True
#         x: array([ 1.8185762 , -0.56547679])

# %% [markdown]
# **Veamos $\beta$ para el ajuste con recta**

# %%
# Mostrar coeficientes
rta1.x
# Out:
# array([ 1.8185762 , -0.56547679])

# %%
# Graficar
plt.figure(figsize=(8,6))
plt.plot(x, y, '*')
plt.plot(x, rta1.x[0]+rta1.x[1]*x, '-k', label='recta ajustada')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
plt.grid()

# %% [markdown]
# ### 2.2. La recta no es buen ajuste... ¿Se ajustará bien una parabola?

# %%
# Definir funcion objetivo y punto inicial
def objmc2(beta,x,y):
    return np.sum((y-(beta[0]+beta[1]*x+beta[2]*x**2))**2)
beta0=[0,0,0]

# %%
# Resolver
rta2=opt.minimize(objmc2,beta0,args=(x,y))
rta2
# Out:
#       fun: 5.3931676234800445
#  hess_inv: array([[ 0.21637184, -0.13994209,  0.01989701],
#        [-0.13994209,  0.0974073 , -0.01442909],
#        [ 0.01989701, -0.01442909,  0.0022046 ]])
#       jac: array([-1.1920929e-07, -1.1920929e-07, -1.1920929e-07])
#   message: 'Optimization terminated successfully.'
#      nfev: 40
#       nit: 5
#      njev: 8
#    status: 0
#   success: True
#         x: array([ 2.40269061, -0.98907005,  0.06472028])

# %% [markdown]
# **Veamos $\beta$ para el ajuste con parábola**

# %%
# Mostrar coeficientes
rta2.x
# Out:
# array([ 2.40269061, -0.98907005,  0.06472028])

# %%
# Graficar recta y parabola ajustadas
plt.figure(figsize=(8,6))
plt.plot(x, y, '*')
plt.plot(x, rta1.x[0]+rta1.x[1]*x, '-k', label='recta ajustada')
plt.plot(x, rta2.x[0]+rta2.x[1]*x+rta2.x[2]*x**2, '-r', label='parabola ajustada')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
plt.grid()

# %% [markdown]
# ### 2.3. Tampoco. Quizá un polinomio cúbico...

# %%
# Definir funcion objetivo y semilla
def objmc3(beta,x,y):
    return np.sum((y-(beta[0]+beta[1]*x+beta[2]*x**2+beta[3]*x**3))**2)
beta0=[0,0,0,0]

# %%
# Resolver
rta3=opt.minimize(objmc3,beta0,args=(x,y))
rta3
# Out:
#       fun: 1.795783879787394
#  hess_inv: array([[ 1.28643833, -1.37983294,  0.43842149, -0.04264282],
#        [-1.37983294,  1.53403453, -0.49935392,  0.04940772],
#        [ 0.43842149, -0.49935392,  0.16588648, -0.01667701],
#        [-0.04264282,  0.04940772, -0.01667701,  0.00169916]])
#       jac: array([ 2.30535865e-04,  1.35585666e-04, -2.39551067e-04,  4.20659781e-05])
#   message: 'Desired error not necessarily achieved due to precision loss.'
#      nfev: 461
#       nit: 9
#      njev: 75
#    status: 2
#   success: False
#         x: array([-0.37477905,  2.22715417, -1.0204595 ,  0.11053572])

# %% [markdown]
# **Veamos $\beta$ para el ajuste con cúbica**

# %%
# Mostrar coeficientes
rta3.x
# Out:
# array([-0.37477905,  2.22715417, -1.0204595 ,  0.11053572])

# %%
# Graficar recta, parabola y cubica
plt.figure(figsize=(8,6))
plt.plot(x, y, '*')
plt.plot(x, rta1.x[0]+rta1.x[1]*x, '-k', label='recta ajustada')
plt.plot(x, rta2.x[0]+rta2.x[1]*x+rta2.x[2]*x**2, '-r', label='parabola ajustada')
plt.plot(x, rta3.x[0]+rta3.x[1]*x+rta3.x[2]*x**2+rta3.x[3]*x**3, '-g', label='3 orden')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
plt.grid()

# %% [markdown]
# Mucho mejor. Entonces, ¿mientras más se suba el orden mejor la aproximación?
#
# ### 2.4. Ajustemos un polinomio de grado 7...

# %%
# Definimos funcion objetivo y semilla
def objmc7(beta, x, y):
    return np.sum((y-beta.dot([x**i for i in range(8)]))**2)

beta0 = np.zeros(8)

# %%
# Resolvemos
rta7=opt.minimize(objmc7,beta0,args=(x,y))
rta7
# Out:
#       fun: 4.836880750630395
#  hess_inv: array([[ 6.43836061e-01, -3.16108819e-01, -2.22080836e-01,
#         -3.98787040e-02,  1.91698143e-01, -8.64108947e-02,
#          1.49087129e-02, -9.11780142e-04],
#        [-3.16108819e-01,  6.68278512e-01, -3.06186149e-01,
#         -1.48702726e-01,  1.75275859e-01, -5.98831163e-02,
#          8.98150084e-03, -5.05831073e-04],
#        [-2.22080836e-01, -3.06186149e-01,  6.76981517e-01,
#         -2.22307547e-01, -7.97691785e-02,  5.77749426e-02,
#         -1.11336649e-02,  7.15131462e-04],
#        [-3.98787040e-02, -1.48702726e-01, -2.22307547e-01,
#          6.92242740e-01, -5.08844874e-01,  1.63817440e-01,
#         -2.45161727e-02,  1.39438272e-03],
#        [ 1.91698143e-01,  1.75275859e-01, -7.97691785e-02,
#         -5.08844874e-01,  4.90681145e-01, -1.75392127e-01,
#          2.77472360e-02, -1.63257217e-03],
#        [-8.64108947e-02, -5.98831163e-02,  5.77749426e-02,
#          1.63817440e-01, -1.75392127e-01,  6.49431603e-02,
# ...

# %% [markdown]
# **De nuevo, veamos $\beta$**

# %%
# Mostrar coeficientes
rta7.x
# Out:
# array([ 1.6261032 ,  0.93877422, -0.69347281, -1.58650655,  1.64495923,
#        -0.60117264,  0.09624738, -0.00569282])

# %% [markdown]
# **¡Cuidado! OVERFITTING o SOBREAJUSTE...**
#
# Observar el tamaño de algunos coeficientes. Cuando los coeficientes son grandes, ¿qué pasa?

# %%
# Grafica de ajustes
plt.figure(figsize=(8,6))
plt.plot(x, y, '*', label='Puntos')
plt.plot(x, rta1.x[0]+rta1.x[1]*x, label='Recta ajustada')
plt.plot(x, rta2.x[0]+rta2.x[1]*x+rta2.x[2]*x**2, label='Parabola ajustada')
plt.plot(x, rta3.x[0]+rta3.x[1]*x+rta3.x[2]*x**2+rta3.x[3]*x**3, label='Cubica ajustada')
plt.plot(x, rta7.x.dot([x**i for i in range(8)]), label='Polinomio grado 7 ajustada')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
plt.grid()

# %% [markdown]
# Es conveniente ver el error como función del orden del polinomio.

# %%
# Error cuadratico
e_ms = []
def obj(b, x, y, n):
    return np.sum((y-b.dot([x**i for i in range(n+1)]))**2)

for i in range(13):
    b0 = np.zeros((i+2,))
    res = opt.minimize(obj, b0, args=(x,y,i+1))
    e_ms.append(res.fun)
    
plt.figure(figsize=(8,5))
plt.plot(np.arange(13)+1, e_ms, 'o')
plt.xlabel('orden')
plt.ylabel('error')
plt.show()

# %% [markdown]
# En efecto, parece que con $3$ es suficiente.

# %% [markdown]
# ## ¿Cómo prevenir el *overfitting* sin importar el orden del modelo?

# %% [markdown]
# ## 3. Regularización
#
# Vimos que la solución de mínimos cuadrados es:
# $$\boldsymbol{\beta}^{ls} = \arg \min_{\boldsymbol{\beta}} \left|\left|\boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\right|\right|^2.$$
#
# Sin embargo, si crecemos el orden del modelo hay overfitting y algunos coeficientes óptimos $\boldsymbol{\beta}$ crecen muchísimo. Que un coeficiente sea muy grande, significa que se le da mucha importancia a alguna característica (que quizá sea ruido... no sirve para predecir).
#
# La regularización consiste en penalizar la magnitud de los coeficientes $\boldsymbol{\beta}$ en el problema de optimización, para que no crezcan tanto.

# %% [markdown]
# ### 3.1. Ridge
#
# $$\boldsymbol{\beta}^{ridge} = \arg \min_{\boldsymbol{\beta}} \left|\left|\boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\right|\right|^2 + \lambda\left|\left|\boldsymbol{\beta}\right|\right|^2$$

# %%
# Definir funcion objetivo de Ridge
def objR(b, x, y, n, l):
    return np.sum((y-b.dot([x**i for i in range(n+1)]))**2)+ l*np.linalg.norm(b)**2
b0 = np.zeros(8)
rtaR = opt.minimize(objR, b0, args=(x,y,7,0.5))

#Graficar
plt.figure(figsize=(8,6))
plt.plot(x, y, '*', label='Puntos')
plt.plot(x, rta7.x.dot([x**i for i in range(8)]), label='Polinomio grado 7 ajustada')
plt.plot(x, rtaR.x.dot([x**i for i in range(8)]), label='Polinomio grado 7 Ridge')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
plt.grid()

# %%
rtaR.x
# Out:
# array([ 0.76707185,  0.64814964, -0.10058963, -0.76544333,  0.67153984,
#        -0.24391617,  0.04016241, -0.00245304])

# %% [markdown]
# ### 3.2. Lasso
#
# $$\boldsymbol{\beta}^{lasso} = \arg \min_{\boldsymbol{\beta}} \left|\left|\boldsymbol{y}-\boldsymbol{X}\boldsymbol{\beta}\right|\right|^2 + \lambda\left|\left|\boldsymbol{\beta}\right|\right|_1$$
#
# La norma 1 no es más que la suma de los valores absolutos de las componentes $\left|\left|\boldsymbol{\beta}\right|\right|_1=\sum_{j=0}^m\left|\beta_j\right|$.

# %%
# Definir funcion objetivo de Lasso
def objL(b, x, y, n, l):
    return np.sum((y-b.dot([x**i for i in range(n+1)]))**2)+ l*np.linalg.norm(b,1)
b0 = np.zeros(8)
rtaL = opt.minimize(objL, b0, args=(x,y,7,0.5))


#Graficar
plt.figure(figsize=(8,6))
plt.plot(x, y, '*', label='Puntos')
plt.plot(x, rta7.x.dot([x**i for i in range(8)]), label='Polinomio Minimos Cuadrados')
plt.plot(x, rtaR.x.dot([x**i for i in range(8)]), label='Polinomio Ridge')
plt.plot(x, rtaL.x.dot([x**i for i in range(8)]), label='Polinomio Lasso')
plt.xlabel('x')
plt.ylabel('y')
plt.legend(loc='best')
plt.grid()

# %%
rtaL.x
# Out:
# array([ 0.90701961, -0.18723935,  0.52652606, -0.62928818,  0.45884168,
#        -0.18755959,  0.03536198, -0.00241062])

# %% [markdown]
# ## 4. Ajuste robusto
#
# Ahora, consideremos de nuevo el caso de la línea recta con un par de puntos atípicos al inicio y al final...

# %%
xr = np.linspace(0, 1, 30)
yr = 10*xr + 2 + np.random.randn(30)

yr[0] = 16
yr[-1] = 0


plt.figure(figsize=(8,6))
plt.plot(xr, yr, '*b')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()

# %% [markdown]
# Solucionamos el problema normalmente...

# %%
# Aplicar Minimos Cuadrados
b0 = np.random.random((2,))
res = opt.minimize(obj, b0, args=(x,y,1))
yhat = np.array([xr**j for j in range(2)]).T.dot(res.x)

plt.figure(figsize=(8,6))
plt.plot(xr, yr, '*b', label = 'datos')
plt.plot(xr, yhat, '-r', label = 'ajuste')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()

# %% [markdown]
# Si estos puntos que parecen ser atípicos, hacen parte de una 'mala medición', vemos que el ajuste que obtenemos a los otros puntos es muy pobre...
#
# **¿Cómo podemos evitar esto?** La respuesta es *ajuste robusto*.
#
# $$\rho (a) = \left\{ {\begin{array}{*{20}{cl}}
# a^2,&\left| a \right| \le d\\
# 2d\left| a \right| - d^2,&\left| a \right| > d
# \end{array}} \right.$$

# %%
# Definir funcion objetivo de Huber
def huber(a, d):
    if np.abs(a)<=d:
        return a**2
    else:
        return d*(2*np.abs(a)-d)

def obj_robust(b, x, y, n, d):
    return np.sum(np.vectorize(huber)(y-b.dot([x**i for i in range(n+1)]), 1.345))

b0 = np.random.random((2,))
res = opt.minimize(obj_robust, b0, args=(xr,yr,1,1.345))
yhat = np.array([xr**j for j in range(2)]).T.dot(res.x)

plt.figure(figsize=(8,6))
plt.plot(xr, yr, '*b', label = 'datos')
plt.plot(xr, yhat, '-r', label = 'ajuste')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()

# %%
res.x
# Out:
# array([1.92298004, 9.6148742 ])

# %% [markdown]
# Mejor...

# %% [markdown]
# ## 5. Actividad
#
# 1. Ajustar polinomios de grado 1 hasta grado 7 a los siguientes datos.
# 2. Graficar el error cuadrático acumulado contra el número de términos, y elegir un polinomio que ajuste bien y su grado no sea muy alto.
# 3. Para el grado de polinomio elegido, realizar el ajuste con ridge con coeficiente de 0.01.
# 4. Comparar los beta.

# %%
def f(x):
    return np.exp(-(x-0.5)**2/(2.0*(0.1/(2*np.sqrt(2*np.log(2))))**2))

# %%
xT=np.linspace(0,1)
yT = f(xT)


plt.figure(figsize=(8,6))
plt.plot(xT, yT, '*b', label = 'datos')
plt.legend(loc = 'best')
plt.xlabel('$x$')
plt.ylabel('$y$')
plt.grid()
plt.show()

# %% [markdown]
# # Avisos
#
# ## Evaluación primer módulo.
#
#
# ## Proyecto:
# ### 1. Elegir integrantes para proyecto. Mínimo 2, máximo 3 (sin excepción). Entregarme una hoja por equipo con los nombres de los integrantes.
# ### 2. Deben elegir un tema para proyecto .
#
# 1.	Cualquiera para ajuste de curva de https://data.worldbank.org/indicator
# 2.	Arbitraje usando programación lineal (Ingeniería Financiera)
# 3.	Planta de tratamiento de aguas residuales de bajo costo (Ingeniería civil) Numerical Methods for Engineers pg 421
# 4.	Problema de descubrir datos ocultos
# 5.	Optimizar diseño de divisor de voltaje (Ingeniería en nanotecnología)
#
# ### 3. Definir Fechas
